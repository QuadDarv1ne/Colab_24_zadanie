# %% [markdown]
# <a href="https://colab.research.google.com/github/QuadDarv1ne/Colab_24_zadanie/blob/main/%2224_%D0%B4%D0%BE%D0%BF%D0%BE%D0%BB%D0%BD%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F_args_kwargs_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#создадим простую функцию складывающую числа
def add1(a,b):
  print(a + b)
add1(2,3)

# %%
#далее, а что если нам потребуется сложить три числа, для этого нам придется изменить функцию в трех местах
def add2(a,b,c):
  print(a+b+c)
add2(2,3,5)

# %% [markdown]
# Но что будем делать если нужно сложить четыре числа, потом 10 чисел, сто чисел.
# Мы же не будем переписывать весь код под каждую задачу создавая переменные.

# %% [markdown]
# Для решения данной задачи призовем АСТЕРИКСА(звездочку) звездочку и напишем  название Любой переменной(обычно args).
# Ключевой момент это использование Астерикса - обозначает упаковку всех входящих аргументов в кортеж
#
#
# ![11782707.jfif](data:image/jpeg;base64,...)

# %%
# создадим функцию
def add3(*args): 
  print(sum(args))
add3()

#даже если мы не введем числа, мы все равно получим результат, без ошибки

# %% [markdown]
# Рассмотрим ситуацию, если мы хотим передать в функцию список, тогда нам необходимо пометить список тоже звездочкой.
# Если мы не пометим звездочкой. то список будет упакован в кортеж и возникнет ошибка.

# %%
def add4(*args): 
  print(sum(args))

l = [1,2,3,4,5,6,7,8,9]

add3(*l)

# %% [markdown]
# В такую конструкцию нельзя передавать генератор

# %%
def gen():
  for i in range (10+1):
    yield i

def add(*args):
  print(args)
  print(sum(args))

l = [1,2,3,4]
add(*gen())

# %% [markdown]
# Вся суть генератора в том, чтобы выдавать информацию по частям, экономя ресурсы машины. В случае, когда мы помечаем генератор звездочкой - астериксом и передаем в функцию для обработки - генератор отрабатывает целиком всю свою последовательность.

# %% [markdown]
# **kwargs - две звездочки означают упаковку в словарь. kwargs - это сокращение от kw - keywords, args - arguments.

# %%
def add(*args, **kwargs):
  print(kwargs)
l = [1, 2, 3]
add(*l, a="1", b="2", c="99")
